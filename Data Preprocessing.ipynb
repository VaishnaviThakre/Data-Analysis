# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.head(10)
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7  1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9  1896  Athens  Aquatics   Swimming          NEUMANN, Paul     AUT    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# ...

# %%
summer.tail(5)
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# # iloc
# iloc is primarily used for selecting rows and columns in a Pandas DataFrame by their integer position or index.
#
# It uses integer-based indexing, meaning you specify the row and column positions by their numerical index rather than by labels.
#
# use iloc to slice, select specific rows/columns, or access specific elements in a DataFrame.
#
# It takes two integers separated by a comma, the first integer represents the row positions, and the second integer represents the column positions.

# %%
sum1 = summer.iloc[1:30]
sum1.head(10)
# Out:
#     Year    City     Sport Discipline                Athlete Country Gender  \
# 1   1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2   1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3   1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4   1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5   1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6   1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7   1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8   1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9   1896  Athens  Aquatics   Swimming          NEUMANN, Paul     AUT    Men
# 10  1896  Athens  Aquatics   Swimming      PEPANOS, Antonios     GRE    Men
#
#                          Event   Medal
# 1               100M Freestyle  Silver
# 2   100M Freestyle For Sailors  Bronze
# ...

# %%
sum2= summer.iloc[40:100]
sum2.head(10)
# Out:
#     Year    City      Sport    Discipline                    Athlete Country  \
# 40  1896  Athens  Athletics     Athletics       HOYT, William Welles     USA
# 41  1896  Athens  Athletics     Athletics              TYLER, Albert     USA
# 42  1896  Athens  Athletics     Athletics      PAPASIDERIS, Georgios     GRE
# 43  1896  Athens  Athletics     Athletics            GARRETT, Robert     USA
# 44  1896  Athens  Athletics     Athletics         GOUSKOS, Miltiadis     GRE
# 45  1896  Athens  Athletics     Athletics          PERSAKIS, Ioannis     GRE
# 46  1896  Athens  Athletics     Athletics            CONNOLLY, James     USA
# 47  1896  Athens  Athletics     Athletics         TUFFERI, Alexandre     FRA
# 48  1896  Athens    Cycling  Cycling Road             BATTEL, Edward     GBR
# 49  1896  Athens    Cycling  Cycling Road  KONSTANTINIDIS, Aristidis     GRE
#
#    Gender                 Event   Medal
# 40    Men            Pole Vault    Gold
# 41    Men            Pole Vault  Silver
# ...

# %% [markdown]
# # isNull
# This method is used to detect missing or NaN (Not a Number) values in a DataFrame or Series.
#
# When applied to a DataFrame or Series, isnull() returns a Boolean mask (True/False) indicating whether each element is missing (NaN) or not.
#
# It returns True for positions where the value is NaN and False otherwise.

# %%
sum1.isnull()
# Out:
#      Year   City  Sport  Discipline  Athlete  Country  Gender  Event  Medal
# 1   False  False  False       False    False    False   False  False  False
# 2   False  False  False       False    False    False   False  False  False
# 3   False  False  False       False    False    False   False  False  False
# 4   False  False  False       False    False    False   False  False  False
# 5   False  False  False       False    False    False   False  False  False
# 6   False  False  False       False    False    False   False  False  False
# 7   False  False  False       False    False    False   False  False  False
# 8   False  False  False       False    False    False   False  False  False
# 9   False  False  False       False    False    False   False  False  False
# 10  False  False  False       False    False    False   False  False  False
# 11  False  False  False       False    False    False   False  False  False
# ...

# %% [markdown]
# # notnull
# This method is the opposite of isnull() and is used to detect non-missing values in a DataFrame or Series.
#
# It returns False for positions where the value is NaN and True otherwise.

# %%
sum1.notnull()
# Out:
#     Year  City  Sport  Discipline  Athlete  Country  Gender  Event  Medal
# 1   True  True   True        True     True     True    True   True   True
# 2   True  True   True        True     True     True    True   True   True
# 3   True  True   True        True     True     True    True   True   True
# 4   True  True   True        True     True     True    True   True   True
# 5   True  True   True        True     True     True    True   True   True
# 6   True  True   True        True     True     True    True   True   True
# 7   True  True   True        True     True     True    True   True   True
# 8   True  True   True        True     True     True    True   True   True
# 9   True  True   True        True     True     True    True   True   True
# 10  True  True   True        True     True     True    True   True   True
# 11  True  True   True        True     True     True    True   True   True
# 12  True  True   True        True     True     True    True   True   True
# ...

# %% [markdown]
# # dropna
# This Pandas function is applied to a DataFrame or Series to remove rows or columns that contain any missing values.
# By default, it removes rows (axis=0) with any NaN values.
# It returns a new DataFrame or Series without the rows or columns containing missing values.

# %%
sum2.dropna()
sum2.head(10)
# Out:
#     Year    City       Sport     Discipline  \
# 40  1896  Athens   Athletics      Athletics
# 41  1896  Athens   Athletics      Athletics
# 42  1896  Athens   Athletics      Athletics
# 43  1896  Athens   Athletics      Athletics
# 44  1896  Athens   Athletics      Athletics
# 45  1896  Athens   Athletics      Athletics
# 46  1896  Athens   Athletics      Athletics
# 47  1896  Athens   Athletics      Athletics
# 48  1896  Athens     Cycling   Cycling Road
# 49  1896  Athens     Cycling   Cycling Road
# 50  1896  Athens     Cycling   Cycling Road
# 51  1896  Athens     Cycling  Cycling Track
# 52  1896  Athens     Cycling  Cycling Track
# 53  1896  Athens     Cycling  Cycling Track
# 54  1896  Athens     Cycling  Cycling Track
# 55  1896  Athens     Cycling  Cycling Track
# 56  1896  Athens     Cycling  Cycling Track
# 57  1896  Athens     Cycling  Cycling Track
# 58  1896  Athens     Cycling  Cycling Track
# 59  1896  Athens     Cycling  Cycling Track
# ...

# %% [markdown]
# # fillna
# fillna() is a method in Pandas used to replace NaN values with a specified value or a predefined strategy.
#
# It can be applied to a DataFrame or Series.

# %%
sum1.fillna("--")
sum1.head(10)
# Out:
#     Year    City     Sport Discipline                Athlete Country Gender  \
# 1   1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2   1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3   1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4   1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5   1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6   1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7   1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8   1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9   1896  Athens  Aquatics   Swimming          NEUMANN, Paul     AUT    Men
# 10  1896  Athens  Aquatics   Swimming      PEPANOS, Antonios     GRE    Men
#
#                          Event   Medal
# 1               100M Freestyle  Silver
# 2   100M Freestyle For Sailors  Bronze
# ...

# %% [markdown]
# # replace
#
# replace() is a method in Pandas used to replace values in a DataFrame or Series with other values.
#
# It can handle various replacements, such as replacing a single value, multiple values, or using a dictionary to specify replacements for different values.

# %%
summer.replace("Men","Male")
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN   Male              100M Freestyle
# 1               HERSCHMANN, Otto     AUT   Male              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE   Male  100M Freestyle For Sailors
# ...

# %% [markdown]
# # interpolate
# interpolate() is a method in Pandas used to fill NaN values in a DataFrame or Series by performing interpolation between existing values.
#
# It can handle different types of interpolation methods such as linear, quadratic, cubic, etc.

# %%
sum2 = summer.interpolate(method="linear")
sum2
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # filter data
# Filtering data in Pandas involves selecting rows or columns based on specific conditions or criteria.

# %%
filtered_data = summer[['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender', 'Event', 'Medal']]
print(filtered_data.head())
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# # creating dataframe using dict
# To create DataFrame from dict of narray/list, all the narray must be of same length. If index is passed then the length index should be equal to the length of arrays. If no index is passed, then by default, index will be range(n) where n is the array length.

# %%
data = {'Name': ['Tom', 'nick', 'krish', 'jack'],
'Age': [20, 21, 19, 18]}

df = pd.DataFrame(data)

df
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %% [markdown]
# # Creating Dataframe from Lists

# %%
data = [10,20,30,40,50,60]

df = pd.DataFrame(data, columns=['Numbers'])

df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60
