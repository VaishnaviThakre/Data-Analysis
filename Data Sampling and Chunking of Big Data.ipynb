# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
sampled_data = summer.sample(frac=0.1, random_state=42)  # 10% sample

# Processing data in chunks 
chunk_size = 10000  # Specify the chunk size
for chunk in pd.read_csv('summer.csv', chunksize=chunk_size):
    # Perform operations on each chunk
    process_chunk(chunk)
# Out:
# Country
# ANZ      29
# ARG      78
# AUS     158
# AUT     101
# BAH       2
#        ...
# URU      74
# USA    1829
# VEN       1
# YUG      78
# ZZX      48
# Name: Medal, Length: 62, dtype: int64
# Country
# AHO       1
# ALG       3
# ARG      21
# AUS     250
# AUT      21
#        ...
# USA    1297
# VEN       7
# YUG     305
# ZAM       1
# ZIM      16
# Name: Medal, Length: 90, dtype: int64
# Country
# AFG      1
# ALG     12
# ARG    140
# ARM      9
# AUS    733
#       ...
# VEN      3
# VIE      2
# YUG     52
# ZAM      1
# ZIM      7
# Name: Medal, Length: 120, dtype: int64
# Country
# AFG     1
# ARG    20
# ARM     2
# AUS    48
# AZE     8
#        ..
# TUR     3
# UKR    12
# USA    91
# UZB     2
# VEN     1
# Name: Medal, Length: 68, dtype: int64

# %%
def process_chunk(chunk):
  
    processed_data = chunk.groupby('Country')['Medal'].count()  

    print(processed_data)

# Loop over chunks and apply the defined function
chunk_size = 10000  
for chunk in pd.read_csv('summer.csv', chunksize=chunk_size):
    process_chunk(chunk)
# Out:
# Country
# ANZ      29
# ARG      78
# AUS     158
# AUT     101
# BAH       2
#        ...
# URU      74
# USA    1829
# VEN       1
# YUG      78
# ZZX      48
# Name: Medal, Length: 62, dtype: int64
# Country
# AHO       1
# ALG       3
# ARG      21
# AUS     250
# AUT      21
#        ...
# USA    1297
# VEN       7
# YUG     305
# ZAM       1
# ZIM      16
# Name: Medal, Length: 90, dtype: int64
# Country
# AFG      1
# ALG     12
# ARG    140
# ARM      9
# AUS    733
#       ...
# VEN      3
# VIE      2
# YUG     52
# ZAM      1
# ZIM      7
# Name: Medal, Length: 120, dtype: int64
# Country
# AFG     1
# ARG    20
# ARM     2
# AUS    48
# AZE     8
#        ..
# TUR     3
# UKR    12
# USA    91
# UZB     2
# VEN     1
# Name: Medal, Length: 68, dtype: int64
